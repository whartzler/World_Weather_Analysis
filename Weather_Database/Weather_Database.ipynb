# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000,90.000, size =2000)
lngs = np.random.uniform(-180.000 ,180.000, size =2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities= []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 757

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]    
        city_weather_description = city_weather['weather'][0]['description']
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | chuy
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | saundatti yellamma
# City not found. Skipping...
# Processing Record 5 of Set 1 | nikolskoye
# Processing Record 6 of Set 1 | fort nelson
# Processing Record 7 of Set 1 | tashtyp
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | makung
# City not found. Skipping...
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | koygorodok
# Processing Record 13 of Set 1 | rocha
# Processing Record 14 of Set 1 | cabo san lucas
# Processing Record 15 of Set 1 | airai
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | kijang
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | nemuro
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 1 | san calixto
# Processing Record 23 of Set 1 | geraldton
# Processing Record 24 of Set 1 | yefremov
# Processing Record 25 of Set 1 | mangan
# Processing Record 26 of Set 1 | dmitriyevka
# Processing Record 27 of Set 1 | puerto ayora
# Processing Record 28 of Set 1 | alofi
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | cidreira
# Processing Record 31 of Set 1 | tuktoyaktuk
# Processing Record 32 of Set 1 | kieta
# Processing Record 33 of Set 1 | balikpapan
# Processing Record 34 of Set 1 | urozhayne
# City not found. Skipping...
# Processing Record 35 of Set 1 | vila
# Processing Record 36 of Set 1 | barrow
# Processing Record 37 of Set 1 | fairbanks
# Processing Record 38 of Set 1 | sitka
# Processing Record 39 of Set 1 | pevek
# Processing Record 40 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 1 | acari
# Processing Record 42 of Set 1 | bonavista
# Processing Record 43 of Set 1 | nuuk
# Processing Record 44 of Set 1 | punta arenas
# Processing Record 45 of Set 1 | karaton
# Processing Record 46 of Set 1 | castro
# Processing Record 47 of Set 1 | soyo
# Processing Record 48 of Set 1 | jamestown
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | tiksi
# Processing Record 1 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 2 | georgetown
# Processing Record 3 of Set 2 | kapoeta
# Processing Record 4 of Set 2 | bathsheba
# Processing Record 5 of Set 2 | mar del plata
# Processing Record 6 of Set 2 | orbetello
# Processing Record 7 of Set 2 | saint-philippe
# Processing Record 8 of Set 2 | bengkulu
# Processing Record 9 of Set 2 | muzhi
# Processing Record 10 of Set 2 | breyten
# Processing Record 11 of Set 2 | exeter
# Processing Record 12 of Set 2 | khatanga
# Processing Record 13 of Set 2 | hobart
# Processing Record 14 of Set 2 | rikitea
# Processing Record 15 of Set 2 | lata
# Processing Record 16 of Set 2 | mount gambier
# Processing Record 17 of Set 2 | lebu
# Processing Record 18 of Set 2 | hithadhoo
# Processing Record 19 of Set 2 | morrope
# Processing Record 20 of Set 2 | cervo
# Processing Record 21 of Set 2 | ribeira grande
# Processing Record 22 of Set 2 | jatai
# Processing Record 23 of Set 2 | atuona
# Processing Record 24 of Set 2 | isangel
# Processing Record 25 of Set 2 | nipawin
# Processing Record 26 of Set 2 | edson
# Processing Record 27 of Set 2 | jishou
# Processing Record 28 of Set 2 | caraballeda
# Processing Record 29 of Set 2 | cortez
# Processing Record 30 of Set 2 | komsomolskiy
# Processing Record 31 of Set 2 | hambantota
# Processing Record 32 of Set 2 | port alfred
# Processing Record 33 of Set 2 | san quintin
# Processing Record 34 of Set 2 | mahon
# Processing Record 35 of Set 2 | cape town
# Processing Record 36 of Set 2 | dingle
# Processing Record 37 of Set 2 | bredasdorp
# Processing Record 38 of Set 2 | fare
# Processing Record 39 of Set 2 | newark
# Processing Record 40 of Set 2 | verkhnyaya sysert
# Processing Record 41 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 2 | broome
# Processing Record 43 of Set 2 | koungou
# Processing Record 44 of Set 2 | goderich
# Processing Record 45 of Set 2 | keetmanshoop
# Processing Record 46 of Set 2 | kalmunai
# Processing Record 47 of Set 2 | karpathos
# Processing Record 48 of Set 2 | carnarvon
# Processing Record 49 of Set 2 | nurota
# Processing Record 50 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 3 | malanje
# Processing Record 2 of Set 3 | formiga
# Processing Record 3 of Set 3 | chokurdakh
# Processing Record 4 of Set 3 | weligama
# Processing Record 5 of Set 3 | kaitangata
# Processing Record 6 of Set 3 | berlevag
# Processing Record 7 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 3 | vaini
# Processing Record 9 of Set 3 | avarua
# Processing Record 10 of Set 3 | upernavik
# Processing Record 11 of Set 3 | laguna
# Processing Record 12 of Set 3 | rio gallegos
# Processing Record 13 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 3 | ukiah
# Processing Record 16 of Set 3 | gualaquiza
# Processing Record 17 of Set 3 | ciudad bolivar
# Processing Record 18 of Set 3 | dikson
# Processing Record 19 of Set 3 | sayhat
# Processing Record 20 of Set 3 | banda aceh
# Processing Record 21 of Set 3 | bulgan
# Processing Record 22 of Set 3 | kisangani
# Processing Record 23 of Set 3 | irati
# Processing Record 24 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 3 | pangnirtung
# Processing Record 26 of Set 3 | constantine
# Processing Record 27 of Set 3 | kiunga
# Processing Record 28 of Set 3 | yulara
# Processing Record 29 of Set 3 | yarmouth
# Processing Record 30 of Set 3 | grindavik
# Processing Record 31 of Set 3 | ekhabi
# Processing Record 32 of Set 3 | falealupo
# City not found. Skipping...
# Processing Record 33 of Set 3 | mahenge
# Processing Record 34 of Set 3 | cap malheureux
# Processing Record 35 of Set 3 | ponta do sol
# Processing Record 36 of Set 3 | palmas
# Processing Record 37 of Set 3 | sao raimundo nonato
# Processing Record 38 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 3 | hokitika
# Processing Record 40 of Set 3 | faya
# Processing Record 41 of Set 3 | high level
# Processing Record 42 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 3 | mataura
# Processing Record 44 of Set 3 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 45 of Set 3 | tiruttani
# Processing Record 46 of Set 3 | hasaki
# Processing Record 47 of Set 3 | vung tau
# Processing Record 48 of Set 3 | yangshan
# Processing Record 49 of Set 3 | nioki
# Processing Record 50 of Set 3 | port lincoln
# Processing Record 1 of Set 4 | portland
# Processing Record 2 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 3 of Set 4 | arraial do cabo
# Processing Record 4 of Set 4 | bara
# Processing Record 5 of Set 4 | kupang
# Processing Record 6 of Set 4 | tiarei
# Processing Record 7 of Set 4 | hays
# Processing Record 8 of Set 4 | chapais
# Processing Record 9 of Set 4 | constitucion
# Processing Record 10 of Set 4 | khash
# Processing Record 11 of Set 4 | praia
# Processing Record 12 of Set 4 | fortuna
# Processing Record 13 of Set 4 | yelizovo
# Processing Record 14 of Set 4 | harrison
# Processing Record 15 of Set 4 | ahipara
# Processing Record 16 of Set 4 | cacapava do sul
# Processing Record 17 of Set 4 | qaanaaq
# Processing Record 18 of Set 4 | nome
# Processing Record 19 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 4 | berdigestyakh
# Processing Record 21 of Set 4 | tacoronte
# Processing Record 22 of Set 4 | samana
# Processing Record 23 of Set 4 | dawlatabad
# Processing Record 24 of Set 4 | cherskiy
# Processing Record 25 of Set 4 | parfino
# Processing Record 26 of Set 4 | ilulissat
# Processing Record 27 of Set 4 | aasiaat
# Processing Record 28 of Set 4 | olinda
# Processing Record 29 of Set 4 | noumea
# Processing Record 30 of Set 4 | coquimbo
# Processing Record 31 of Set 4 | sao joao da barra
# Processing Record 32 of Set 4 | santa cruz del sur
# Processing Record 33 of Set 4 | muzaffargarh
# Processing Record 34 of Set 4 | usinsk
# Processing Record 35 of Set 4 | saint-georges
# Processing Record 36 of Set 4 | narsaq
# Processing Record 37 of Set 4 | bethel
# Processing Record 38 of Set 4 | esperance
# Processing Record 39 of Set 4 | namatanai
# Processing Record 40 of Set 4 | blagoyevo
# Processing Record 41 of Set 4 | mahebourg
# Processing Record 42 of Set 4 | margate
# Processing Record 43 of Set 4 | rio tercero
# Processing Record 44 of Set 4 | san andres
# Processing Record 45 of Set 4 | san cristobal
# Processing Record 46 of Set 4 | cayenne
# Processing Record 47 of Set 4 | vardo
# Processing Record 48 of Set 4 | aginskoye
# Processing Record 49 of Set 4 | axim
# Processing Record 50 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 1 of Set 5 | kavaratti
# Processing Record 2 of Set 5 | saint george
# Processing Record 3 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 5 | iqaluit
# Processing Record 6 of Set 5 | arman
# Processing Record 7 of Set 5 | novoomskiy
# Processing Record 8 of Set 5 | lindi
# Processing Record 9 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 10 of Set 5 | waingapu
# Processing Record 11 of Set 5 | tsabong
# Processing Record 12 of Set 5 | puerto leguizamo
# Processing Record 13 of Set 5 | toora-khem
# Processing Record 14 of Set 5 | padang
# Processing Record 15 of Set 5 | bahia blanca
# Processing Record 16 of Set 5 | kysyl-syr
# Processing Record 17 of Set 5 | kruisfontein
# Processing Record 18 of Set 5 | dalbandin
# Processing Record 19 of Set 5 | asau
# Processing Record 20 of Set 5 | bobo dioulasso
# Processing Record 21 of Set 5 | alexandria
# Processing Record 22 of Set 5 | taybad
# Processing Record 23 of Set 5 | namibe
# Processing Record 24 of Set 5 | lasa
# Processing Record 25 of Set 5 | manjacaze
# Processing Record 26 of Set 5 | zemio
# Processing Record 27 of Set 5 | kargil
# Processing Record 28 of Set 5 | do gonbadan
# Processing Record 29 of Set 5 | kaiyuan
# Processing Record 30 of Set 5 | pasni
# Processing Record 31 of Set 5 | east london
# Processing Record 32 of Set 5 | nefteyugansk
# Processing Record 33 of Set 5 | leningradskiy
# Processing Record 34 of Set 5 | beringovskiy
# Processing Record 35 of Set 5 | corralillo
# Processing Record 36 of Set 5 | hirara
# Processing Record 37 of Set 5 | sharjah
# Processing Record 38 of Set 5 | kambarka
# Processing Record 39 of Set 5 | sao filipe
# Processing Record 40 of Set 5 | megalopoli
# Processing Record 41 of Set 5 | samarai
# Processing Record 42 of Set 5 | nanortalik
# Processing Record 43 of Set 5 | tilichiki
# Processing Record 44 of Set 5 | auki
# Processing Record 45 of Set 5 | luis correia
# Processing Record 46 of Set 5 | tuatapere
# Processing Record 47 of Set 5 | kribi
# Processing Record 48 of Set 5 | saint-joseph
# Processing Record 49 of Set 5 | dukat
# Processing Record 50 of Set 5 | polson
# Processing Record 1 of Set 6 | bukama
# Processing Record 2 of Set 6 | itoman
# Processing Record 3 of Set 6 | esso
# Processing Record 4 of Set 6 | grand gaube
# Processing Record 5 of Set 6 | bilibino
# Processing Record 6 of Set 6 | ituporanga
# Processing Record 7 of Set 6 | sabha
# Processing Record 8 of Set 6 | sola
# Processing Record 9 of Set 6 | hamilton
# Processing Record 10 of Set 6 | vestmannaeyjar
# Processing Record 11 of Set 6 | sehore
# Processing Record 12 of Set 6 | zhigansk
# Processing Record 13 of Set 6 | port hawkesbury
# Processing Record 14 of Set 6 | kapustin yar-1
# City not found. Skipping...
# Processing Record 15 of Set 6 | carauari
# Processing Record 16 of Set 6 | bandarbeyla
# Processing Record 17 of Set 6 | kasongo-lunda
# Processing Record 18 of Set 6 | nezhinka
# Processing Record 19 of Set 6 | havre-saint-pierre
# Processing Record 20 of Set 6 | salinopolis
# Processing Record 21 of Set 6 | palora
# Processing Record 22 of Set 6 | beyneu
# Processing Record 23 of Set 6 | tougue
# Processing Record 24 of Set 6 | codrington
# Processing Record 25 of Set 6 | nantucket
# Processing Record 26 of Set 6 | pochutla
# Processing Record 27 of Set 6 | lompoc
# Processing Record 28 of Set 6 | bagotville
# Processing Record 29 of Set 6 | hualmay
# Processing Record 30 of Set 6 | rawson
# Processing Record 31 of Set 6 | viedma
# Processing Record 32 of Set 6 | abbeville
# Processing Record 33 of Set 6 | caborca
# Processing Record 34 of Set 6 | natal
# Processing Record 35 of Set 6 | nishihara
# Processing Record 36 of Set 6 | kiama
# Processing Record 37 of Set 6 | deputatskiy
# Processing Record 38 of Set 6 | baghdad
# Processing Record 39 of Set 6 | sistranda
# Processing Record 40 of Set 6 | zhuhai
# Processing Record 41 of Set 6 | egersund
# Processing Record 42 of Set 6 | ziway
# Processing Record 43 of Set 6 | khandbari
# Processing Record 44 of Set 6 | souillac
# Processing Record 45 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 6 | tasiilaq
# Processing Record 47 of Set 6 | yeppoon
# Processing Record 48 of Set 6 | ancud
# Processing Record 49 of Set 6 | port hardy
# Processing Record 50 of Set 6 | harper
# Processing Record 1 of Set 7 | caravelas
# Processing Record 2 of Set 7 | saldanha
# Processing Record 3 of Set 7 | renukut
# Processing Record 4 of Set 7 | abnub
# Processing Record 5 of Set 7 | privolzhskiy
# Processing Record 6 of Set 7 | burica
# City not found. Skipping...
# Processing Record 7 of Set 7 | zabid
# Processing Record 8 of Set 7 | sug-aksy
# City not found. Skipping...
# Processing Record 9 of Set 7 | sawtell
# Processing Record 10 of Set 7 | faanui
# Processing Record 11 of Set 7 | bani
# Processing Record 12 of Set 7 | gizo
# Processing Record 13 of Set 7 | severo-kurilsk
# Processing Record 14 of Set 7 | mamakan
# Processing Record 15 of Set 7 | atar
# Processing Record 16 of Set 7 | carlos chagas
# Processing Record 17 of Set 7 | adrar
# Processing Record 18 of Set 7 | batagay
# Processing Record 19 of Set 7 | saskylakh
# Processing Record 20 of Set 7 | mutsamudu
# City not found. Skipping...
# Processing Record 21 of Set 7 | kodiak
# Processing Record 22 of Set 7 | tual
# Processing Record 23 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 7 | lerdo
# Processing Record 25 of Set 7 | hofn
# Processing Record 26 of Set 7 | mahajanga
# Processing Record 27 of Set 7 | katobu
# Processing Record 28 of Set 7 | westport
# Processing Record 29 of Set 7 | christchurch
# Processing Record 30 of Set 7 | kavieng
# Processing Record 31 of Set 7 | walvis bay
# Processing Record 32 of Set 7 | bekobod
# Processing Record 33 of Set 7 | arica
# Processing Record 34 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 7 | murakami
# Processing Record 36 of Set 7 | labuhan
# Processing Record 37 of Set 7 | poum
# Processing Record 38 of Set 7 | yakeshi
# Processing Record 39 of Set 7 | mercedes
# Processing Record 40 of Set 7 | porto novo
# Processing Record 41 of Set 7 | mangaratiba
# Processing Record 42 of Set 7 | port blair
# Processing Record 43 of Set 7 | barroquinha
# Processing Record 44 of Set 7 | thompson
# Processing Record 45 of Set 7 | longyearbyen
# Processing Record 46 of Set 7 | laredo
# Processing Record 47 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 48 of Set 7 | vao
# Processing Record 49 of Set 7 | shubarkuduk
# Processing Record 50 of Set 7 | linchuan
# City not found. Skipping...
# Processing Record 1 of Set 8 | okha
# Processing Record 2 of Set 8 | saint anthony
# Processing Record 3 of Set 8 | margherita
# Processing Record 4 of Set 8 | manica
# Processing Record 5 of Set 8 | porto de moz
# Processing Record 6 of Set 8 | jambi
# Processing Record 7 of Set 8 | makakilo city
# Processing Record 8 of Set 8 | pakwach
# City not found. Skipping...
# Processing Record 9 of Set 8 | vojens
# Processing Record 10 of Set 8 | vokhma
# Processing Record 11 of Set 8 | la ronge
# Processing Record 12 of Set 8 | kahului
# Processing Record 13 of Set 8 | kyren
# Processing Record 14 of Set 8 | klaksvik
# Processing Record 15 of Set 8 | vila franca do campo
# Processing Record 16 of Set 8 | otradnoye
# Processing Record 17 of Set 8 | amqui
# Processing Record 18 of Set 8 | jiuquan
# Processing Record 19 of Set 8 | karratha
# Processing Record 20 of Set 8 | palmer
# Processing Record 21 of Set 8 | ampanihy
# Processing Record 22 of Set 8 | tukrah
# Processing Record 23 of Set 8 | mount isa
# Processing Record 24 of Set 8 | bambous virieux
# Processing Record 25 of Set 8 | worland
# Processing Record 26 of Set 8 | ketchikan
# Processing Record 27 of Set 8 | burnie
# Processing Record 28 of Set 8 | rawdon
# Processing Record 29 of Set 8 | nabire
# Processing Record 30 of Set 8 | aykhal
# Processing Record 31 of Set 8 | petrykiv
# Processing Record 32 of Set 8 | tigil
# Processing Record 33 of Set 8 | larreynaga
# Processing Record 34 of Set 8 | jaipur
# Processing Record 35 of Set 8 | baruun-urt
# Processing Record 36 of Set 8 | victoria
# Processing Record 37 of Set 8 | hangu
# Processing Record 38 of Set 8 | neftcala
# Processing Record 39 of Set 8 | cuamba
# Processing Record 40 of Set 8 | hirado
# Processing Record 41 of Set 8 | nadym
# Processing Record 42 of Set 8 | udachnyy
# Processing Record 43 of Set 8 | guantanamo
# Processing Record 44 of Set 8 | estelle
# Processing Record 45 of Set 8 | pilao arcado
# City not found. Skipping...
# Processing Record 46 of Set 8 | haldia
# Processing Record 47 of Set 8 | saint-pierre
# Processing Record 48 of Set 8 | swinoujscie
# Processing Record 49 of Set 8 | bubaque
# Processing Record 50 of Set 8 | jizan
# Processing Record 1 of Set 9 | port-cartier
# Processing Record 2 of Set 9 | santa rita
# Processing Record 3 of Set 9 | am timan
# Processing Record 4 of Set 9 | clyde river
# Processing Record 5 of Set 9 | limon
# Processing Record 6 of Set 9 | omboue
# Processing Record 7 of Set 9 | xining
# Processing Record 8 of Set 9 | perth
# Processing Record 9 of Set 9 | vale
# Processing Record 10 of Set 9 | tomatlan
# Processing Record 11 of Set 9 | kishanpur
# Processing Record 12 of Set 9 | nosy varika
# Processing Record 13 of Set 9 | taoudenni
# Processing Record 14 of Set 9 | presidencia roque saenz pena
# Processing Record 15 of Set 9 | cartagena
# Processing Record 16 of Set 9 | luderitz
# Processing Record 17 of Set 9 | tunduru
# City not found. Skipping...
# Processing Record 18 of Set 9 | logan lake
# Processing Record 19 of Set 9 | galle
# Processing Record 20 of Set 9 | belen
# Processing Record 21 of Set 9 | houma
# Processing Record 22 of Set 9 | sciacca
# Processing Record 23 of Set 9 | bartica
# Processing Record 24 of Set 9 | provideniya
# Processing Record 25 of Set 9 | touros
# Processing Record 26 of Set 9 | point pedro
# Processing Record 27 of Set 9 | mareeba
# Processing Record 28 of Set 9 | ardakan
# Processing Record 29 of Set 9 | hami
# Processing Record 30 of Set 9 | katsuura
# Processing Record 31 of Set 9 | anage
# Processing Record 32 of Set 9 | torbay
# Processing Record 33 of Set 9 | pisco
# Processing Record 34 of Set 9 | aklavik
# Processing Record 35 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 36 of Set 9 | salalah
# Processing Record 37 of Set 9 | taunggyi
# Processing Record 38 of Set 9 | bellingham
# Processing Record 39 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 40 of Set 9 | egvekinot
# Processing Record 41 of Set 9 | sept-iles
# Processing Record 42 of Set 9 | alghero
# Processing Record 43 of Set 9 | husavik
# Processing Record 44 of Set 9 | port hedland
# Processing Record 45 of Set 9 | mekhe
# Processing Record 46 of Set 9 | lorengau
# Processing Record 47 of Set 9 | taltal
# Processing Record 48 of Set 9 | polis
# Processing Record 49 of Set 9 | naze
# Processing Record 50 of Set 9 | ponta delgada
# Processing Record 1 of Set 10 | fremont
# Processing Record 2 of Set 10 | severnoye
# Processing Record 3 of Set 10 | tautira
# Processing Record 4 of Set 10 | marzuq
# Processing Record 5 of Set 10 | ola
# Processing Record 6 of Set 10 | sechura
# Processing Record 7 of Set 10 | havoysund
# Processing Record 8 of Set 10 | norwich
# Processing Record 9 of Set 10 | nhulunbuy
# Processing Record 10 of Set 10 | yar-sale
# Processing Record 11 of Set 10 | along
# Processing Record 12 of Set 10 | nalut
# Processing Record 13 of Set 10 | buckeye
# Processing Record 14 of Set 10 | mandalgovi
# Processing Record 15 of Set 10 | paamiut
# Processing Record 16 of Set 10 | toba
# Processing Record 17 of Set 10 | mayo
# Processing Record 18 of Set 10 | matagami
# Processing Record 19 of Set 10 | nyurba
# Processing Record 20 of Set 10 | ranong
# Processing Record 21 of Set 10 | male
# Processing Record 22 of Set 10 | russellville
# Processing Record 23 of Set 10 | valdivia
# Processing Record 24 of Set 10 | aksu
# Processing Record 25 of Set 10 | evensk
# Processing Record 26 of Set 10 | puerto colombia
# Processing Record 27 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 28 of Set 10 | inhambane
# Processing Record 29 of Set 10 | kargasok
# Processing Record 30 of Set 10 | shache
# Processing Record 31 of Set 10 | hanzhong
# Processing Record 32 of Set 10 | barra da estiva
# Processing Record 33 of Set 10 | arlit
# Processing Record 34 of Set 10 | ambilobe
# Processing Record 35 of Set 10 | katsiveli
# City not found. Skipping...
# Processing Record 36 of Set 10 | bonthe
# Processing Record 37 of Set 10 | moree
# Processing Record 38 of Set 10 | alyangula
# Processing Record 39 of Set 10 | serra talhada
# Processing Record 40 of Set 10 | matara
# Processing Record 41 of Set 10 | itarema
# Processing Record 42 of Set 10 | fernie
# Processing Record 43 of Set 10 | ejea de los caballeros
# Processing Record 44 of Set 10 | avera
# Processing Record 45 of Set 10 | carutapera
# Processing Record 46 of Set 10 | bati
# Processing Record 47 of Set 10 | makamba
# Processing Record 48 of Set 10 | moctezuma
# Processing Record 49 of Set 10 | markala
# Processing Record 50 of Set 10 | kedrovyy
# Processing Record 1 of Set 11 | chegdomyn
# Processing Record 2 of Set 11 | mimongo
# Processing Record 3 of Set 11 | conde
# Processing Record 4 of Set 11 | los llanos de aridane
# Processing Record 5 of Set 11 | giyani
# Processing Record 6 of Set 11 | lukoyanov
# Processing Record 7 of Set 11 | joutseno
# Processing Record 8 of Set 11 | morgantown
# Processing Record 9 of Set 11 | jacmel
# Processing Record 10 of Set 11 | gurskoye
# City not found. Skipping...
# Processing Record 11 of Set 11 | roald
# Processing Record 12 of Set 11 | sao domingos
# Processing Record 13 of Set 11 | olafsvik
# Processing Record 14 of Set 11 | allende
# Processing Record 15 of Set 11 | jeremie
# Processing Record 16 of Set 11 | sur
# Processing Record 17 of Set 11 | port elizabeth
# Processing Record 18 of Set 11 | mecca
# Processing Record 19 of Set 11 | flin flon
# Processing Record 20 of Set 11 | alice springs
# Processing Record 21 of Set 11 | loikaw
# Processing Record 22 of Set 11 | sandnessjoen
# Processing Record 23 of Set 11 | timizart
# Processing Record 24 of Set 11 | quatre cocos
# Processing Record 25 of Set 11 | valparaiso
# Processing Record 26 of Set 11 | uglegorsk
# Processing Record 27 of Set 11 | valley
# Processing Record 28 of Set 11 | bintulu
# Processing Record 29 of Set 11 | valley city
# Processing Record 30 of Set 11 | agadez
# Processing Record 31 of Set 11 | northam
# Processing Record 32 of Set 11 | huarmey
# Processing Record 33 of Set 11 | shingu
# Processing Record 34 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 11 | norman wells
# Processing Record 36 of Set 11 | dobryanka
# Processing Record 37 of Set 11 | midland
# Processing Record 38 of Set 11 | popondetta
# Processing Record 39 of Set 11 | albanel
# Processing Record 40 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 41 of Set 11 | tonekabon
# Processing Record 42 of Set 11 | najran
# Processing Record 43 of Set 11 | lagoa
# Processing Record 44 of Set 11 | bosaso
# Processing Record 45 of Set 11 | santiago de las vegas
# Processing Record 46 of Set 11 | tororo
# Processing Record 47 of Set 11 | zhoucun
# Processing Record 48 of Set 11 | kismayo
# Processing Record 49 of Set 11 | hobyo
# Processing Record 50 of Set 11 | pozo colorado
# Processing Record 1 of Set 12 | cam ranh
# Processing Record 2 of Set 12 | xiangfan
# Processing Record 3 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 4 of Set 12 | general roca
# Processing Record 5 of Set 12 | zeya
# Processing Record 6 of Set 12 | mon
# Processing Record 7 of Set 12 | bardiyah
# Processing Record 8 of Set 12 | russell
# Processing Record 9 of Set 12 | gujan-mestras
# Processing Record 10 of Set 12 | neufchateau
# Processing Record 11 of Set 12 | waupun
# Processing Record 12 of Set 12 | san vicente
# Processing Record 13 of Set 12 | zapolyarnyy
# Processing Record 14 of Set 12 | lubao
# Processing Record 15 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 16 of Set 12 | brae
# Processing Record 17 of Set 12 | ca mau
# Processing Record 18 of Set 12 | kjustendil
# Processing Record 19 of Set 12 | cochrane
# Processing Record 20 of Set 12 | parczew
# Processing Record 21 of Set 12 | korla
# Processing Record 22 of Set 12 | elko
# Processing Record 23 of Set 12 | forestville
# Processing Record 24 of Set 12 | altay
# Processing Record 25 of Set 12 | broken hill
# Processing Record 26 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 27 of Set 12 | cloquet
# Processing Record 28 of Set 12 | khani
# Processing Record 29 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 12 | marsa matruh
# Processing Record 31 of Set 12 | saint stephen
# Processing Record 32 of Set 12 | duz
# City not found. Skipping...
# Processing Record 33 of Set 12 | mengyin
# Processing Record 34 of Set 12 | azul
# Processing Record 35 of Set 12 | mamou
# Processing Record 36 of Set 12 | karmana
# City not found. Skipping...
# Processing Record 37 of Set 12 | dafeng
# Processing Record 38 of Set 12 | goulburn
# Processing Record 39 of Set 12 | te anau
# Processing Record 40 of Set 12 | san rafael del sur
# Processing Record 41 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 42 of Set 12 | flinders
# Processing Record 43 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 12 | tura
# Processing Record 45 of Set 12 | marrakesh
# Processing Record 46 of Set 12 | buala
# Processing Record 47 of Set 12 | cockburn town
# Processing Record 48 of Set 12 | lipin bor
# Processing Record 49 of Set 12 | oktyabrskiy
# Processing Record 50 of Set 12 | davila
# Processing Record 1 of Set 13 | ayan
# Processing Record 2 of Set 13 | sheridan
# Processing Record 3 of Set 13 | urfa
# City not found. Skipping...
# Processing Record 4 of Set 13 | mokhsogollokh
# Processing Record 5 of Set 13 | maragogi
# Processing Record 6 of Set 13 | loa janan
# Processing Record 7 of Set 13 | portel
# Processing Record 8 of Set 13 | robertsport
# Processing Record 9 of Set 13 | shinyanga
# Processing Record 10 of Set 13 | charters towers
# Processing Record 11 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 12 of Set 13 | nizhnevartovsk
# Processing Record 13 of Set 13 | muravlenko
# Processing Record 14 of Set 13 | barcelos
# Processing Record 15 of Set 13 | betong
# Processing Record 16 of Set 13 | whitianga
# Processing Record 17 of Set 13 | san policarpo
# Processing Record 18 of Set 13 | batagay-alyta
# Processing Record 19 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 13 | omurtag
# Processing Record 21 of Set 13 | bacuit
# City not found. Skipping...
# Processing Record 22 of Set 13 | urumqi
# Processing Record 23 of Set 13 | fort dodge
# Processing Record 24 of Set 13 | hervey bay
# Processing Record 25 of Set 13 | winslow
# Processing Record 26 of Set 13 | inta
# Processing Record 27 of Set 13 | sompeta
# Processing Record 28 of Set 13 | upata
# Processing Record 29 of Set 13 | tenkodogo
# Processing Record 30 of Set 13 | acapulco
# Processing Record 31 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 32 of Set 13 | acobamba
# Processing Record 33 of Set 13 | kishapu
# Processing Record 34 of Set 13 | puerto narino
# Processing Record 35 of Set 13 | merauke
# Processing Record 36 of Set 13 | itanagar
# Processing Record 37 of Set 13 | jijiga
# Processing Record 38 of Set 13 | meulaboh
# Processing Record 39 of Set 13 | nouadhibou
# Processing Record 40 of Set 13 | santa clara
# Processing Record 41 of Set 13 | lodja
# Processing Record 42 of Set 13 | la macarena
# Processing Record 43 of Set 13 | bizhbulyak
# Processing Record 44 of Set 13 | witu
# Processing Record 45 of Set 13 | general pico
# Processing Record 46 of Set 13 | coihaique
# Processing Record 47 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 48 of Set 13 | boyolangu
# Processing Record 49 of Set 13 | vilhena
# Processing Record 50 of Set 13 | triunfo
# Processing Record 1 of Set 14 | novyy starodub
# Processing Record 2 of Set 14 | rovaniemi
# Processing Record 3 of Set 14 | sakaiminato
# Processing Record 4 of Set 14 | muromtsevo
# Processing Record 5 of Set 14 | gushikawa
# Processing Record 6 of Set 14 | la asuncion
# Processing Record 7 of Set 14 | edd
# Processing Record 8 of Set 14 | borsad
# Processing Record 9 of Set 14 | veraval
# Processing Record 10 of Set 14 | zhoucheng
# Processing Record 11 of Set 14 | maniitsoq
# Processing Record 12 of Set 14 | yarim
# Processing Record 13 of Set 14 | trofors
# Processing Record 14 of Set 14 | acajutla
# Processing Record 15 of Set 14 | svetlogorsk
# Processing Record 16 of Set 14 | aranos
# Processing Record 17 of Set 14 | vila velha
# Processing Record 18 of Set 14 | maceio
# Processing Record 19 of Set 14 | kabirwala
# Processing Record 20 of Set 14 | zhetybay
# City not found. Skipping...
# Processing Record 21 of Set 14 | gat
# Processing Record 22 of Set 14 | guacui
# Processing Record 23 of Set 14 | celestun
# Processing Record 24 of Set 14 | tambacounda
# Processing Record 25 of Set 14 | sobolevo
# Processing Record 26 of Set 14 | kutum
# Processing Record 27 of Set 14 | vysokaya gora
# Processing Record 28 of Set 14 | luena
# Processing Record 29 of Set 14 | diamantino
# Processing Record 30 of Set 14 | lavrentiya
# Processing Record 31 of Set 14 | kadoma
# Processing Record 32 of Set 14 | kashan
# Processing Record 33 of Set 14 | corowa
# Processing Record 34 of Set 14 | virginia beach
# Processing Record 35 of Set 14 | kungurtug
# Processing Record 36 of Set 14 | tambopata
# Processing Record 37 of Set 14 | honiara
# Processing Record 38 of Set 14 | campoverde
# Processing Record 39 of Set 14 | loreto
# Processing Record 40 of Set 14 | at-bashi
# Processing Record 41 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 42 of Set 14 | puerto del rosario
# Processing Record 43 of Set 14 | san teodoro
# Processing Record 44 of Set 14 | dumas
# Processing Record 45 of Set 14 | talcahuano
# Processing Record 46 of Set 14 | aquiraz
# Processing Record 47 of Set 14 | zhezkazgan
# Processing Record 48 of Set 14 | dandong
# Processing Record 49 of Set 14 | manavalakurichi
# Processing Record 50 of Set 14 | wanning
# Processing Record 1 of Set 15 | yichun
# Processing Record 2 of Set 15 | trincomalee
# Processing Record 3 of Set 15 | wiwili
# Processing Record 4 of Set 15 | orsk
# Processing Record 5 of Set 15 | sungairaya
# Processing Record 6 of Set 15 | isla vista
# Processing Record 7 of Set 15 | harindanga
# Processing Record 8 of Set 15 | lagos
# Processing Record 9 of Set 15 | vostok
# Processing Record 10 of Set 15 | xam nua
# Processing Record 11 of Set 15 | rawah
# Processing Record 12 of Set 15 | slonim
# Processing Record 13 of Set 15 | gemena
# Processing Record 14 of Set 15 | iralaya
# Processing Record 15 of Set 15 | safaga
# Processing Record 16 of Set 15 | groningen
# Processing Record 17 of Set 15 | malmesbury
# Processing Record 18 of Set 15 | falmouth
# Processing Record 19 of Set 15 | qingquan
# Processing Record 20 of Set 15 | birin
# Processing Record 21 of Set 15 | yumen
# Processing Record 22 of Set 15 | ballina
# Processing Record 23 of Set 15 | kununurra
# Processing Record 24 of Set 15 | alizai
# Processing Record 25 of Set 15 | mackay
# Processing Record 26 of Set 15 | seoul
# Processing Record 27 of Set 15 | kokkola
# Processing Record 28 of Set 15 | sarankhola
# Processing Record 29 of Set 15 | alamosa
# Processing Record 30 of Set 15 | gamba
# Processing Record 31 of Set 15 | cagliari
# Processing Record 32 of Set 15 | tabou
# Processing Record 33 of Set 15 | novopetrovskoye
# Processing Record 34 of Set 15 | ilyich
# Processing Record 35 of Set 15 | richards bay
# Processing Record 36 of Set 15 | dunedin
# Processing Record 37 of Set 15 | elizabeth city
# Processing Record 38 of Set 15 | gobabis
# Processing Record 39 of Set 15 | tiznit
# Processing Record 40 of Set 15 | marsh harbour
# Processing Record 41 of Set 15 | jarjis
# City not found. Skipping...
# Processing Record 42 of Set 15 | turukhansk
# Processing Record 43 of Set 15 | madras
# Processing Record 44 of Set 15 | ribeira brava
# Processing Record 45 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 46 of Set 15 | gouyave
# Processing Record 47 of Set 15 | lingyuan
# Processing Record 48 of Set 15 | chateaubelair
# Processing Record 49 of Set 15 | marawi
# Processing Record 50 of Set 15 | basoko
# Processing Record 1 of Set 16 | san carlos de bariloche
# Processing Record 2 of Set 16 | gwembe
# Processing Record 3 of Set 16 | seddon
# Processing Record 4 of Set 16 | pingliang
# Processing Record 5 of Set 16 | tutoia
# Processing Record 6 of Set 16 | praia da vitoria
# Processing Record 7 of Set 16 | del rio
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 698

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  New Norfolk      AU -42.7826  147.0587     46.92        70          44
# 1         Chuy      UY -33.6971  -53.4616     80.06        59          65
# 2       Albany      US  42.6001  -73.9662     33.39        46          56
# 3   Nikolskoye      RU  59.7035   30.7861     24.69        97          91
# 4  Fort Nelson      CA  58.8053 -122.7002     21.94        77          75
# 5      Tashtyp      RU  52.7939   89.8983     11.84        83          48
# 6         Hilo      US  19.7297 -155.0900     77.61        94          75
# 7        Bluff      NZ -46.6000  168.3333     58.80        87          76
# 8    Busselton      AU -33.6500  115.3333     49.73        81           0
# 9   Koygorodok      RU  60.4450   50.9968     11.21        94           8
#
#    Wind Speed Current Description
# 0        8.01    scattered clouds
# 1       12.82       broken clouds
# 2        3.00       broken clouds
# 3        4.03     overcast clouds
# 4        0.00       broken clouds
# 5       10.29    scattered clouds
# 6        4.61       moderate rain
# 7        7.58       broken clouds
# 8       11.52           clear sky
# 9        3.65           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  New Norfolk      AU -42.7826  147.0587     46.92        70          44
# 1         Chuy      UY -33.6971  -53.4616     80.06        59          65
# 2       Albany      US  42.6001  -73.9662     33.39        46          56
# 3   Nikolskoye      RU  59.7035   30.7861     24.69        97          91
# 4  Fort Nelson      CA  58.8053 -122.7002     21.94        77          75
# 5      Tashtyp      RU  52.7939   89.8983     11.84        83          48
# 6         Hilo      US  19.7297 -155.0900     77.61        94          75
# 7        Bluff      NZ -46.6000  168.3333     58.80        87          76
# 8    Busselton      AU -33.6500  115.3333     49.73        81           0
# 9   Koygorodok      RU  60.4450   50.9968     11.21        94           8
#
#    Wind Speed Current Description
# 0        8.01    scattered clouds
# 1       12.82       broken clouds
# 2        3.00       broken clouds
# 3        4.03     overcast clouds
# 4        0.00       broken clouds
# 5       10.29    scattered clouds
# 6        4.61       moderate rain
# 7        7.58       broken clouds
# 8       11.52           clear sky
# 9        3.65           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="WeatherPy_Database")
